# %%
import csv

# %%
with open("D:/EA3434Z_Tsawwassen/InputData/20211216_VegEdits2/Composite.csv") as f:
    reader = csv.reader(f)
    for id, row in enumerate(reader):
        if float(str(row[0]).split()[2]) != 0 and int(str(row[0]).split()[3]) != 0:
            print(row)
# Out:
# ['491247.985 5433064.054 2.84102 4']
# ['491248.050 5433064.054 2.84138 4']
# ['491247.920 5433063.989 2.84323 4']
# ['491247.985 5433063.989 2.83965 4']
# ['491248.050 5433063.989 2.84195 4']
# ['491248.115 5433063.989 2.84926 4']
# ['491247.855 5433063.924 2.84872 4']
# ['491247.920 5433063.924 2.83747 4']
# ['491247.985 5433063.924 2.84105 4']
# ['491248.050 5433063.924 2.84588 4']
# ['491248.115 5433063.924 2.85178 4']
# ['491248.180 5433063.924 2.85188 4']
# ['491247.790 5433063.859 2.85096 4']
# ['491247.855 5433063.859 2.84697 4']
# ['491247.920 5433063.859 2.8471 4']
# ['491247.985 5433063.859 2.84827 4']
# ['491248.050 5433063.859 2.85231 4']
# ['491248.115 5433063.859 2.85229 4']
# ['491248.180 5433063.859 2.85131 4']
# ['491248.245 5433063.859 2.85141 4']
# ['491247.725 5433063.794 2.8491 4']
# ['491247.790 5433063.794 2.84611 4']
# ['491247.855 5433063.794 2.84016 4']
# ['491247.920 5433063.794 2.84513 4']
# ['491247.985 5433063.794 2.84809 4']
# ...

# %%
l =['10 20 30 40']

# %%
str(l[0]).split()[3] == 40
